# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

print("Librerías importadas correctamente para el modelo MultinomialNB.")
# Out:
# Librerías importadas correctamente para el modelo MultinomialNB.

# %%
df = pd.read_csv('spam.csv', encoding = 'latin-1')

# %%
df.head(5)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df_nueva_data = df[['v1', 'v2']]
df_nueva_data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df_nueva_data = df_nueva_data.rename(
    columns = {
        'v1': 'categoria',
        'v2': 'descripcion'
    }
)

# %%
df_nueva_data.head(5)
# Out:
#   categoria                                        descripcion
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...

# %%
X = df_nueva_data['descripcion']
y = df_nueva_data['categoria']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 19)

# %%
modelo = MultinomialNB()
modelo.fit(X_train_vec, y_train)

print("Modelo MultinomialNB entrenado exitosamente.")
# Out:
# Modelo MultinomialNB entrenado exitosamente.

# %%
vectorizador = CountVectorizer()
X_train_vec = vectorizador.fit_transform(X_train)
X_test_vec = vectorizador.transform(X_test)

# %%
y_pred = modelo.predict(X_test_vec)
print(y_pred)
# Out:
# ['ham' 'spam' 'ham' ... 'spam' 'spam' 'ham']

# %%
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.9856459330143541

# %%
f1 = f1_score(y_test, y_pred, pos_label = 'spam')
print(f1)
# Out:
# 0.9504132231404959

# %%
report = classification_report(y_test, y_pred, target_names=['spam', 'ham'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         spam       0.99      1.00      0.99      1425
#          ham       0.97      0.93      0.95       247
#
#     accuracy                           0.99      1672
#    macro avg       0.98      0.96      0.97      1672
# weighted avg       0.99      0.99      0.99      1672
